# %% [markdown]
# # Sklearn Pipeline for Scoring New Data

# %%
import pickle
import pandas as pd

# %% [markdown]
# # Import Data

# %%
# load the local dataset 
df = pd.read_csv('../data/bank_customer_dataset.csv')

df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# # Load Model Artifacts

# %%
with open('../artifacts/numeric_imputer.pickle', 'rb') as filename: # trained model to impute missing numeric data
    numeric_imputer = pickle.load(filename)

with open('../artifacts/capper.pickle', 'rb') as filename: # trained model to cap outliers
    capper = pickle.load(filename)   

with open('../artifacts/model.pickle', 'rb') as filename: # trained random forrest classifier
    model = pickle.load(filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# e:\GoogleDrive\Beruf\Freelancing\Code_Repo\Customer_Analytics\Marketing-Sales-Customer-Segmentation-Webapp\experiment\05_customer_seg_bankdata_scoring_pipeline.ipynb Cell 6 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/e%3A/GoogleDrive/Beruf/Freelancing/Code_Repo/Customer_Analytics/Marketing-Sales-Customer-Segmentation-Webapp/experiment/05_customer_seg_bankdata_scoring_pipeline.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> with open('../artifacts/capper.pickle', 'rb') as filename: # trained model to cap outliers
#       <a href='vscode-notebook-cell:/e%3A/GoogleDrive/Beruf/Freelancing/Code_Repo/Customer_Analytics/Marketing-Sales-Customer-Segmentation-Webapp/experiment/05_customer_seg_bankdata_scoring_pipeline.ipynb#W6sZmlsZQ%3D%3D?line=4'>5</a>     capper = pickle.load(filename)
# ----> <a href='vscode-notebook-cell:/e%3A/GoogleDrive/Beruf/Freelancing/Code_Repo/Customer_Analytics/Marketing-Sales-Customer-Segmentation-Webapp/experiment/05_customer_seg_bankdata_scoring_pipeline.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a> with open('../artifacts/model.pickle', 'rb') as filename: # trained random forrest classifier
#       <a href='vscode-notebook-cell:/e%3A/GoogleDrive/Beruf/Freelancing/Code_Repo/Customer_Analytics/Marketing-Sales-Customer-Segmentation-Webapp/experiment/05_customer_seg_bankdata_scoring_pipeline.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     model = pickle.load(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../artifacts/model.pickle'

# %% [markdown]
# # Transform Dataset

# %%
# get numeric and categorical columns
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_columns = df.select_dtypes(include=numerics).columns.to_list()

# %%
# impute mising numeric features
df_numeric = pd.DataFrame(
    numeric_imputer.transform(df[numeric_columns]), 
    columns=numeric_columns, 
    index=df.index)

# remove outliers
df[numeric_columns] = capper.transform(df[numeric_columns])

# predict cluster
labels = model.predict(df)

# add cluster label to df
df['cluster'] = labels

df.head()
# Out:
# c:\Users\Nutzer\.conda\envs\customer_analytics\lib\site-packages\sklearn\preprocessing\_encoders.py:188: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
#     Age    fnlwgt  Education-Num  Capital Gain  Capital Loss  Hours per week  \
# 0  39.0   77516.0           13.0        2174.0           0.0            40.0
# 1  50.0   83311.0           13.0           0.0           0.0            13.0
# 2  38.0  215646.0            9.0           0.0           0.0            40.0
# 3  53.0  234721.0            7.0           0.0           0.0            40.0
# 4  28.0  338409.0           13.0           0.0           0.0            40.0
#
#           Workclass  Education      Martial Status       Occupation  \
# 0         State-gov  Bachelors       Never-married     Adm-clerical
# 1  Self-emp-not-inc  Bachelors  Married-civ-spouse  Exec-managerial
# 2           Private    HS-grad            Divorced             Rare
# 3           Private       Rare  Married-civ-spouse             Rare
# 4           Private  Bachelors  Married-civ-spouse   Prof-specialty
#
#     Relationship   Race     Sex        Country Income  cluster
# 0  Not-in-family  White    Male  United-States  <=50K        0
# 1        Husband  White    Male  United-States  <=50K        0
# 2  Not-in-family  White    Male  United-States  <=50K        2
# 3        Husband  Black    Male  United-States  <=50K        0
# 4           Wife  Black  Female           Rare  <=50K        0

# %%
# Cluster Counts
df['cluster'].value_counts()
# Out:
# 0    27198
# 1    12208
# 2     8246
# 3     1190
# Name: cluster, dtype: int64

# %%
# Cluster Centers
pd.concat([
    df.groupby(by='cluster').mean(),
    df.groupby(by='cluster').aggregate(pd.Series.mode)[categorical_columns] ],
    axis=1)
# Out:
#                Age         fnlwgt  Education-Num  Capital Gain  Capital Loss  \
# cluster
# 0        40.911580  192300.261221      10.287227    806.467609     77.508181
# 1        42.688991  180531.280159       9.951016    851.457887     42.345697
# 2        26.558951  186843.276619       9.152559     78.423230     27.467518
# 3        28.379832  188394.921701      13.015126    110.082353     48.792694
#
#          Hours per week Workclass  Education      Martial Status  \
# cluster
# 0             40.389680   Private       Rare  Married-civ-spouse
# 1             43.643237   Private    HS-grad  Married-civ-spouse
# 2             35.059433   Private    HS-grad       Never-married
# 3             40.818258   Private  Bachelors       Never-married
#
#               Occupation   Relationship   Race     Sex        Country Income
# cluster
# 0        Exec-managerial  Not-in-family  White    Male  United-States  <=50K
# 1           Craft-repair        Husband  White    Male  United-States  <=50K
# 2                   Rare      Own-child  White    Male  United-States  <=50K
# 3        Exec-managerial  Not-in-family  White  Female  United-States  <=50K
