# %%
import pandas as pd
from pycaret.clustering import *

# %%
# import dataset
data = pd.read_csv('../data/Marketing_data.csv')
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
# init setup
s = setup(data, normalize=True)
# Out:
# c:\Users\Nutzer\.conda\envs\pycaret_latest\lib\site-packages\pycaret\internal\pipeline.py:134: UserWarning: Persisting input arguments took 1.03s to run.
# If this happens often in your code, it can cause performance problems
# (results will be correct in all cases).
# The reason for this is probably some large input arguments for a wrapped
#  function (e.g. large strings).
# THIS IS A JOBLIB ISSUE. If you can, kindly provide the joblib's team with an
#  example so that they can fix the problem.
#   X, y, fitted_transformer = self._memory_fit(
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [4], line 2
#       1 # init setup
# ----> 2 s = setup(data, normalize=True)
#
# ...
